# %%
from tkinter import *
from tkcalendar import DateEntry
r = Tk()
#change the background color to purple
r.configure(background='purple')
#change the title to application form
r.title('Application Form')
#add the labels and entries 
l1 = Label(r,text='First Name').grid(row=0,column=0)
e1 = Entry(r,width=20).grid(row=0,column=1)
l2 = Label(r,text='Last Name').grid(row=1,column=0)
e2 = Entry(r,width=20).grid(row=1,column=1)
l3 = Label(r,text='Date of Birth').grid(row=2,column=0)
e3 = DateEntry(r,width=20).grid(row=2,column=1)
l4 = Label(r,text='Email Address').grid(row=3,column=0)
e4 = Entry(r,width=20).grid(row=3,column=1)
l5 = Label(r,text='Phone Number').grid(row=4,column=0)
e5 = Entry(r,width=20).grid(row=4,column=1)
l6 = Label(r,text='Address').grid(row=5,column=0)
e6 = Entry(r,width=20).grid(row=5,column=1)
l7 = Label(r,text='City').grid(row=6,column=0)
e7 = Entry(r,width=20).grid(row=6,column=1)
l8 = Label(r,text='Pin Code').grid(row=7,column=0)
e8 = Entry(r,width=20).grid(row=7,column=1)
l9 = Label(r,text='State').grid(row=8,column=0)
e9 = Entry(r,width=20).grid(row=8,column=1)
l10 = Label(r,text='Country').grid(row=9,column=0)
e10 = Entry(r,width=20).grid(row=9,column=1)
l11 = Label(r,text='Hobbies').grid(row=10,column=0)
c1 = Checkbutton(r,text='Reading').grid(row=10,column=1)
c2 = Checkbutton(r,text='Singing').grid(row=10,column=2)
c3 = Checkbutton(r,text='Dancing').grid(row=10,column=3)
c4 = Checkbutton(r,text='Sketching').grid(row=10,column=4)
c5 = Checkbutton(r,text='Others').grid(row=11,column=1)
e11 = Entry(r,width=20).grid(row=11,column=2)
l12 = Label(r,text='Qualification').grid(row=12,column=0)
#labels for sl.no. board percentage year of passing
l13 = Label(r,text='Sl.No.').grid(row=13,column=0)
slno1 = Label(r,text='1').grid(row=14,column=0)
slno2 = Label(r,text='2').grid(row=15,column=0)
slno3 = Label(r,text='3').grid(row=16,column=0)
slno4 = Label(r,text='4').grid(row=17,column=0)
l14 = Label(r,text='Board').grid(row=13,column=1)
#four entries under the board column
e14 = Entry(r,width=20).grid(row=14,column=1)
e15 = Entry(r,width=20).grid(row=15,column=1)
e16 = Entry(r,width=20).grid(row=16,column=1)
e17 = Entry(r,width=20).grid(row=17,column=1)
l15 = Label(r,text='Percentage').grid(row=13,column=2)
#four entries under the percentage column
e18 = Entry(r,width=20).grid(row=14,column=2)
e19 = Entry(r,width=20).grid(row=15,column=2)
e20 = Entry(r,width=20).grid(row=16,column=2)
e21 = Entry(r,width=20).grid(row=17,column=2)
l16 = Label(r,text='Year of Passing').grid(row=13,column=3)
#four entries under the year of passing column
e22 = Entry(r,width=20).grid(row=14,column=3)
e23 = Entry(r,width=20).grid(row=15,column=3)
e24 = Entry(r,width=20).grid(row=16,column=3)
e25 = Entry(r,width=20).grid(row=17,column=3)
l13 = Label(r,text='Courses Applied for').grid(row=18,column=0)
#four radiobuttons under the courses applied for column for BCA B.Com B.Sc. B.A
c6 = Radiobutton(r,text='BCA').grid(row=18,column=1)
c7 = Radiobutton(r,text='B.Com').grid(row=18,column=2)
c8 = Radiobutton(r,text='B.Sc').grid(row=18,column=3)
c9 = Radiobutton(r,text='B.A').grid(row=18,column=4)
# 2 buttons at the bottom for submit and reset
b1 = Button(r,text='Submit').grid(row=19,column=0)
b2 = Button(r,text='Reset').grid(row=19,column=1)
r.mainloop()
